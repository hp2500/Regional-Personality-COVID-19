# %%
import pandas as pd
from itertools import chain

# %%
dict_pickle = pd.read_pickle('/Users/hp2500/Google Drive/STUDY/Columbia/Research/Corona/Data/features.p')

df_temp = pd.DataFrame()
for i in dict_pickle.items():
    for j in i[1].items():
        row_temp = pd.Series(chain([i[0]], [j[0]], j[1]))
        df_temp = df_temp.append(row_temp, ignore_index=True)

# %%
df_temp
# Out:
#               0           1          2         3         4             5   \
# 0      2134548.0  2020-01-23 -10.557506  8.673283  0.195859  9.336594e-02
# 1      2134548.0  2020-01-24 -18.197377  7.667633  0.061154  1.327716e-02
# 2      2134548.0  2020-01-25 -10.941697  8.910158  0.180052  2.070269e-01
# 3      2134548.0  2020-01-26 -18.477568  7.433439  0.058223  1.054906e-02
# 4      2134548.0  2020-01-27 -18.165413  7.354366  0.060839  1.034049e-02
# ...          ...         ...        ...       ...       ...           ...
# 15213  2124853.0  2020-01-27  -8.859086  8.361301  0.052094  6.856592e-03
# 15214  2124853.0  2020-01-28 -23.516620  1.110085  0.000302  1.683176e-08
# 15215  2140618.0  2020-01-27 -15.948642  8.751055  0.329698  1.541982e-01
# 15216  2150922.0  2020-01-28 -14.918550  9.864837  0.438486  2.632895e-01
# 15217  2150922.0  2020-01-29 -15.612984  8.700047  0.461869  3.466183e-01
#
#              6         7         8         9   ...         25        26  \
# 0      0.025382  0.002950  1.044187  2.153473  ...  17.420000  0.002401
# 1      0.002386  0.000000  0.198515  0.156111  ...  23.999722  0.002405
# 2      0.025014  0.009153  1.196711  1.276516  ...  17.976389  0.002200
# 3      0.001773  0.000000 -0.000000  0.043802  ...  23.999722  0.001756
# 4      0.001955  0.000000  0.304636  0.105336  ...  23.999722  0.001214
# ...         ...       ...       ...       ...  ...        ...       ...
# 15213  0.096465  0.000000 -0.000000  0.794547  ...   4.176389  0.001647
# 15214  0.000055  0.000000 -0.000000 -0.000000  ...   3.771944  0.000146
# 15215  0.008630  0.014218  1.549826  1.142143  ...   5.227222  0.031949
# 15216  0.017299  0.020761  2.086769  2.273248  ...  23.341667  0.049703
# 15217  0.009071  0.033898  1.329661  1.354039  ...   5.613611  0.056132
#
#              27        28        29        30        31        32        33  \
# 0      0.003674  0.010589  0.044638  0.221327  0.665397  0.951926  0.210738
# 1      0.004127  0.008876  0.022146  0.059252  0.139636  0.238038  0.050376
# 2      0.004368  0.012009  0.035215  0.183343  0.416357  0.788155  0.171333
# 3      0.002592  0.007462  0.017035  0.050703  0.190564  0.300690  0.043241
# 4      0.002508  0.008229  0.023145  0.069263  0.163946  0.249839  0.061034
# ...         ...       ...       ...       ...       ...       ...       ...
# 15213  0.001895  0.005191  0.013342  0.057346  0.136652  0.183065  0.052155
# 15214  0.000170  0.000244  0.000367  0.000393  0.000408  0.000413  0.000149
# 15215  0.053114  0.101435  0.190803  0.394037  0.770068  1.228760  0.292602
# 15216  0.079961  0.146802  0.301433  0.540593  0.918544  1.184122  0.393791
# 15217  0.080269  0.144981  0.272854  0.500495  0.914408  1.598587  0.355514
#
#              34
# 0      0.676853
# 1      0.473182
# 2      0.729117
# 3      0.557236
# 4      0.511215
# ...         ...
# 15213  0.687435
# 15214 -0.656914
# 15215  0.389155
# 15216  0.214656
# 15217  0.280632
#
# [15218 rows x 35 columns]

# %%
col_names = ['uid', 'date', 'loc_var_value', 'dis_value', 'speed_mean', 'speed_var', 
 'convex_hull_value', 'transition_time_value', 'dis_ent_value', 'raw_ent_value', 
 'dis_var', 'dis_mean', 'max_dis_from_home', 'max_dis', 'num_gps_records', 
 'num_cluster_value', 'time_at_each_loc_value', 'location_changes_value', 
 'ent_value', 'norm_ent_value', 'rad_gyration_value', 'per_1', 'per_2', 'per_3', 
 'per_cluster','per_at_home', 'q5', 'q10', 'q25', 'q50', 'q75', 'q90', 'q95', 
 'iqr', 'skew']

# %%
df_temp.columns = col_names

# %%
df_temp.to_csv('../Data/mp_features.csv')

# %% [markdown]
# #

# %%
filename = "/Users/hp2500/Downloads/0710.3742.pdf"
parsedPDF = parser.from_file(file_name)
print(parsedPDF['content'])
print(parsedPDF['metadata']) # its in a dictionary format.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-31d7869b33b9> in <module>
# ----> 1 import tika
#       2 from tika import parser
#       3
#       4 filename = "/Users/hp2500/Downloads/0710.3742.pdf"
#       5 parsedPDF = parser.from_file(file_name)
#
# ModuleNotFoundError: No module named 'tika'
